# %% [markdown]
# Base file to process all network density data from different datasets and make a dataframe to be imported for figure 1 or 2 files
# #1 Network density analysis for figure 1

# %%
#import required libraries
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import os
from glob import glob
import pandas as pd
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
from re import findall as find

# %%
#Analysis folders for network density figure 1
#Analysis folders for network density figure 1

folder1="H:\\PHD_data\\Imaging_et_analysis\\NikSD\\2023\\03_Mar\\25032023_EVPLMONetwork\\NetworkAnalysisControl\\"
folder2="H:\\PHD_data\\Imaging_et_analysis\\NikSD\\2023\\02_Feb\\14022023_Mypt\\NetworkAnalysis_Mypt\\"
folder3="H:\\PHD_data\\Imaging_et_analysis\\NikSD\\2023\\10_Oct\\24102023_caRhoA\\NetworkDensityControl\\"
folder4="H:\\PHD_data\\Imaging_et_analysis\\NikSD\\2023\\10_Oct\\30102023_caRhoiA\\NetworkDensityAnalysis\\NetworkDensityControl_Pos001\\"

# %%
def get_data(folder):
    files=glob(folder+"*.csv")
    timedict={"folder1":,"folder2":folder2,"folder3":,"folder4":180}
