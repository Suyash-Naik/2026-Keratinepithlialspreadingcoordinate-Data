# %%
import io
import tifffile
import numpy as np
import matplotlib.pyplot as plt
import tkinter as tk
from tkinter import filedialog
import glob
import pandas as pd

# %%
# Create a Tkinter root object
root = tk.Tk()
root.withdraw()  # Hide the root window

# Launch a folder dialog box and store the selected folder path in a variable
folder_path = filedialog.askdirectory()

# Print the selected folder path
print(folder_path)
# Out:
# 2023-03-02 13:10:19.986 python[8839:433578] +[CATransaction synchronize] called within transaction
# 2023-03-02 13:10:20.845 python[8839:433578] +[CATransaction synchronize] called within transaction
# 2023-03-02 13:10:22.525 python[8839:433578] +[CATransaction synchronize] called within transaction
# 2023-03-02 13:10:28.792 python[8839:433578] +[CATransaction synchronize] called within transaction
# /Volumes/snaik/PHD_data/Imaging_et_analysis/NikSD/2021/11_Nov/22112021/Pos001/OrthoView

# %%
filelist=glob.glob(folder_path+"/*6.csv")
for iterer1 in range(len(filelist)):
    pd.read_csv(filelist[iterer1])
